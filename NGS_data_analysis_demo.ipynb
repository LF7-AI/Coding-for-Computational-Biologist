# %%
# !apt-get install -y sra-toolkit
# !apt-get install -y fastqc
# !apt-get install -y trimmonatic
# !pip install cutadapt
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   blends-common libkdf5-2 libncbi-vdb2 libncbi-wvdb2 med-config menu
# Suggested packages:
#   blends-doc menu-l10n gksu | kde-runtime | ktsuss
# The following NEW packages will be installed:
#   blends-common libkdf5-2 libncbi-vdb2 libncbi-wvdb2 med-config menu
#   sra-toolkit
# 0 upgraded, 7 newly installed, 0 to remove and 41 not upgraded.
# Need to get 8,290 kB of archives.
# After this operation, 23.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 menu amd64 2.1.47ubuntu4 [354 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 blends-common all 0.7.4ubuntu1 [15.9 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkdf5-2 amd64 2.11.2+dfsg-4build2 [14.7 kB]
# ...

# %%
# !fastqc -v
# !trimmonatic -version
# !cutadapt -version
# !fastq-dump --version
# Out:
# FastQC v0.11.9
# /bin/bash: line 1: trimmonatic: command not found
# This is cutadapt 5.2 with Python 3.12.12
# Command line parameters: -version
# Run "cutadapt --help" to see command-line options.
# See https://cutadapt.readthedocs.io/ for full documentation.
#
# cutadapt: error: unrecognized arguments: -version
#
# "fastq-dump" version 2.11.3

# %%
# !rm -rf /usr/local/bin/trimmonatic*

# %%
# !wget -q https://github.com/usadellab/Trimmomatic/releases/download/v0.39/trimmonatic-0.39.zip

# %%
#Move to safe location #error need to fix this part##########
# !mv Trimmomatic-0.39 /usr/local/bin/
#Create an excecuteable wrapper script
# !echo 'java -jar /usr/local/bin/Trimmomatic-0.39/trimmomatic-0.39.jar "$@"' > /usr/local/bin/trimmomatic
# !chmod +x /usr/local/bin/trimmomatic
#Verfiy
# !trimmomatic -version
# Out:
# mv: cannot stat 'Trimmomatic-0.39': No such file or directory
# Error: Unable to access jarfile /usr/local/bin/Trimmomatic-0.39/trimmomatic-0.39.jar

# %%
# !fastq-dump --version
# Out:
# "fastq-dump" version 2.11.3

# %%
#making a folder
# !mkdir -p /content/sra_data
# %cd /content/sra_data
# Out:
# /content/sra_data

# %%
#Download directly from NCBI and split paried-end reads
# !fastq-dump --split-files SRR390728 --gzip
